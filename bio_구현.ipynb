# %% [markdown]
# <a href="https://colab.research.google.com/github/silverstar0727/bio_informatics/blob/master/bio_%EA%B5%AC%ED%98%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 구글 드라이브 연동
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd /content/gdrive/My\ Drive/machine_learning
# Out:
# /content/gdrive/My Drive/machine_learning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Train_Data = pd.read_csv("data_set_ALL_AML_train.csv")
Test_Data = pd.read_csv("data_set_ALL_AML_independent.csv")
labels = pd.read_csv("actual.csv", index_col = 'patient')
Train_Data.head()
# Out:
#                       Gene Description Gene Accession Number  ...   33 call.37
# 0  AFFX-BioB-5_at (endogenous control)        AFFX-BioB-5_at  ... -135       A
# 1  AFFX-BioB-M_at (endogenous control)        AFFX-BioB-M_at  ... -186       A
# 2  AFFX-BioB-3_at (endogenous control)        AFFX-BioB-3_at  ...  -70       A
# 3  AFFX-BioC-5_at (endogenous control)        AFFX-BioC-5_at  ...  337       A
# 4  AFFX-BioC-3_at (endogenous control)        AFFX-BioC-3_at  ... -407       A
#
# [5 rows x 78 columns]

# %%
Test_Data.head()
# Out:
#                       Gene Description Gene Accession Number  ...   62 call.33
# 0  AFFX-BioB-5_at (endogenous control)        AFFX-BioB-5_at  ... -176       A
# 1  AFFX-BioB-M_at (endogenous control)        AFFX-BioB-M_at  ... -284       A
# 2  AFFX-BioB-3_at (endogenous control)        AFFX-BioB-3_at  ...  -81       A
# 3  AFFX-BioC-5_at (endogenous control)        AFFX-BioC-5_at  ...    9       A
# 4  AFFX-BioC-3_at (endogenous control)        AFFX-BioC-3_at  ... -294       A
#
# [5 rows x 70 columns]

# %%
print(Train_Data.isna().sum().max())
print(Test_Data.isna().sum().max())
# Out:
# 0
# 0

# %%
cols = [col for col in Test_Data.columns if 'call' in col]
test = Test_Data.drop(cols, 1)
cols = [col for col in Train_Data.columns if 'call' in col]
train = Train_Data.drop(cols, 1)

# %%
patients = [str(i) for i in range(1, 73, 1)]
df_all = pd.concat([train, test], axis = 1)[patients]
df_all = df_all.T

# %%
df_all["patient"] = pd.to_numeric(patients)
labels["cancer"]= pd.get_dummies(Actual.cancer, drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-1f31307b4f7f> in <module>()
#       1 df_all["patient"] = pd.to_numeric(patients)
# ----> 2 labels["cancer"]= pd.get_dummies(Actual.cancer, drop_first=True)
#
# NameError: name 'Actual' is not defined

# %%
Data = pd.merge(df_all, labels, on="patient")
Data.head()
# Out:
#      0    1    2    3    4    5  ...  7125  7126  7127  7128  patient  cancer
# 0 -214 -153  -58   88 -295 -558  ...   329    36   191   -37        1     ALL
# 1 -139  -73   -1  283 -264 -400  ...   295    11    76   -14        2     ALL
# 2  -76  -49 -307  309 -376 -650  ...   777    41   228   -41        3     ALL
# 3 -135 -114  265   12 -419 -585  ...   170   -50   126   -91        4     ALL
# 4 -106 -125  -76  168 -230 -284  ...   314    14    56   -25        5     ALL
#
# [5 rows x 7131 columns]
